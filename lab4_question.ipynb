# %% [markdown]
# # INTRODUCTION TO DATA SCIENCE (MDA3003)**
#
# **Pengenalan Kepada Sains Data (MDA3003)**
#
#
# >R.U.Gobithaasan (2022). Introduction of Data Science, Lectures for Undergraduate Degree Program B.Sc (Data Analytics), Faculty of Ocean Engineering Technology, University Malaysia Terengganu.
# https://sites.google.com/site/gobithaasan/
#
#
# <p align="center">
#      © 2022 R.U. Gobithaasan All Rights Reserved.
#
# </p>

# %% [markdown]
# ### Content of this course is adopted from the following books.
#   - [Introduction to Data Mining by Pang-ning Tan, Michael Steinbach, Vipin Kumar](https://www-users.cse.umn.edu/~kumar001/dmbook/index.php)
#   - [Data Mining and Machine Learning: Fundamental Concepts and Algorithms by
# Mohammed J. Zaki and Wagner Meira, Jr](https://dataminingbook.info/)
#
#  - [Hands-On Machine Learning with Scikit-Learn, Keras, and TensorFlow: Concepts, Tools, and Techniques to Build Intelligent Systems by Aurélien Géron](https://github.com/ageron/handson-ml2)
#
#   - [Book: Data Science from Scratch First Principles with Python](https://www.oreilly.com/library/view/data-science-from/9781492041122/)
#   - [Github: Data Science from Scratch First Principles with Python](https://github.com/joelgrus/data-science-from-scratch)
#   - Jesus Rogel-Salazar, Data Science and Analytics with Python, CRC Press, Year: 2017
#   - Jesus Rogel-Salazar, Advanced Data Science and Analytics with Python, CRC Press, Year: 2020
#   - online ML work by [Jean de Dieu Nyandwi](https://nyandwi.com/machine_learning_complete/)

# %% [markdown]
# ## Fill up the following declaration details:
# **I certify that this report is my own work, based on my personal study and/or research. I also certify that this report has not previously been submitted for assessment in any other unit, and that I have not copied in part or whole or otherwise plagiarised the work of other students and/or persons.**
# - Name:
# - Matrix Number:
# - Date:

# %% [markdown]
# # MARKS
#
# | ATTRIBUTES    | MARKS |
# | ----------- | ----------- |
# | 1. MODULE/FUNCTION     |       |
# | 2. SYNTAX/CODE/ REASONING  |      |
# | 3. DOCUMENTATION    |       |
#
#
# **inaccurate code, didn't achieve final PCA reduction**
#
# <u>Marks For MODULE/FUNCTION:
#
# - Amateur (+1): Unable to use the right module/function.
# - Acceptable (+2): Module /function is somewhat suitable.
# - Admirable (+3): Module /function is suitable and partially solved the problem.
# - Exceptional (+4): Module /function is are clearly identified and the problem is solved without errors.
#
# <u> Marks For SYNTAX/CODE/ REASONING :
#
# - Amateur (+1): Code is illogical, simplistic, inconsistent or does not work.
# - Acceptable (+2): Code contains some elements of logic and/or creative insight.
# - Admirable (+3): Code is mostly logical, complete, and consistent. Demonstrates some unique or creative insight.
# - Exceptional (+4): Code is consistently creative, complete and often unique.
#
# <u> Marks For DOCUMENTATION:
#
# - Amateur (+1): Explanation is not stated or vague.
# - Acceptable (+2): Able to explain with some justification.
# - Admirable (+3): Conclusion mostly from results of analysis.
# - Exceptional (+4): Full justification presented following clear concluding statement. Specifics and multiple perspectives are present.

# %% [markdown]
# ## General Instruction:
# Let say your matrix number is S54321. For computation below, ignore the first letter and use your matrix number by letting $\mathbf{(\alpha , \beta, \gamma, \kappa, \lambda) =(5,4,3,2,1)}$. Hence replace explicitly the values of greek letters as $\alpha = 5, \beta = 4, \gamma = 3, \kappa = 2, \lambda =1$.
#
#
# For example:
#
# **Q0.** Compute $(\beta * \gamma * \kappa)+{\lambda})$:

# %% [markdown]
# # Lab 4: Feature engineering and selection

# %% [markdown]
# Lab 2 Content:
#
# **1. Feature Scaling: bird.csv:**
# - normalization
# - standardization
#
# **2. Feature Selection: California House**
#  - correlation
#
# **3. Dimensionality Reduction: bird.csv:**
#  - Principal Component Analysis

# %% [markdown]
# # Prelimineries

# %% [markdown]
# <b>Q1:Install and import the following and identify its version:</b>
#
# 1. Pandas
# 2. sklearn
# 3. numpy
# 4. seaborn
# 5. plotly : for interactive visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly

# %%
import sklearn, pandas, numpy, seaborn,plotly

print(pandas.__version__)
print(sklearn.__version__)
print(numpy.__version__)
print(seaborn.__version__)
# Out:
# 1.4.3
# 1.0.2
# 1.22.4
# 0.11.2

# %% [markdown]
# # Feature Scaling

# %% [markdown]
# ### Dummy data

# %% [markdown]
# **Q1.**  Import the bird.csv as dataframe and do the following:
# 1. Print the first three lines of the data and identify the number of objects.
# 2. Plot the dataset and its mean value using plotly package.
# 2. Using SK Learn package, normalize and standardize the data and re-plot to see the difference
# 3. Using the equation shown in the lecture, standardize the data and re-plot. TIPS: find the mean and standard deviation of this dataset first. Check the new set of mean value if its zero.

# %%
import plotly.graph_objects as go
import plotly.io as pio
 
pio.templates.default = "plotly" # ["plotly", "plotly_white", "plotly_dark", "ggplot2", "seaborn", "simple_white", "none"]:


fig = go.Figure()

# the dataset
fig.add_trace(
    go.Scatter(
        x=bird['# x'],
        y=bird[' y'],
        mode='markers',
        marker=dict(
        size=10,
        colorscale='Viridis',   # choose a colorscale
        opacity=0.9
    )
        
))

# the mean value
fig.add_trace(
    go.Scatter(
        x=[bird.mean()[0]],
        y=[bird.mean()[1]],
        mode='markers',
        marker=dict(
        size=20,
        colorscale='Viridis',   # choose a colorscale
        opacity=0.9
    )
    
    )

)

fig.update_yaxes(scaleanchor = "x",scaleratio = 1)

fig.update_layout(
    title="Bird",
    showlegend=False,
    xaxis_title="X Axis",
    yaxis_title="Y Axis ",
    font=dict(
        family="Courier New, monospace",
        size=18,
        color="Blue",
    )
)

# %% [markdown]
# ## Normalization and Standardization Using SKLearn package.

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
import plotly.graph_objects as go
import plotly.io as pio
 
pio.templates.default = "plotly" # ["plotly", "plotly_white", "plotly_dark", "ggplot2", "seaborn", "simple_white", "none"]:


fig = go.Figure()

fig.add_trace(
    go.Scatter(
        x=bird_s[:,0],
        y=bird_s[:,1],
        mode='markers',
        marker=dict(
        size=10,
        colorscale='Viridis',   # choose a colorscale
        opacity=0.9
    )
        
))

fig.add_trace(
    go.Scatter(
        x=[0],
        y=[0],
        mode='markers',
        marker=dict(
        size=20,
        colorscale='Viridis',   # choose a colorscale
        opacity=0.9
    )
    
    )

)
        

fig.update_yaxes(scaleanchor = "x",scaleratio = 1)
fig.update_layout(
    title="Bird_standardized",
    showlegend=False,
    xaxis_title="X Axis",
    yaxis_title="Y Axis ",
    font=dict(
        family="Courier New, monospace",
        size=18,
        color="Blue",
    )
)

# %%
import plotly.graph_objects as go
import plotly.io as pio
 
pio.templates.default = "plotly" # ["plotly", "plotly_white", "plotly_dark", "ggplot2", "seaborn", "simple_white", "none"]:


fig = go.Figure()

fig.add_trace(
    go.Scatter(
        x=bird_n[:,0],
        y=bird_n[:,1],
        mode='markers',
        marker=dict(
        size=10,
        colorscale='Viridis',   # choose a colorscale
        opacity=0.9
    )
        
))

     

fig.update_yaxes(scaleanchor = "x",scaleratio = 1)
fig.update_layout(
    title="Bird_normalized",
    showlegend=False,
    xaxis_title="X Axis",
    yaxis_title="Y Axis ",
    font=dict(
        family="Courier New, monospace",
        size=18,
        color="Blue",
    )
)

# %% [markdown]
# ## Standardization using the lecture note:

# %%
import plotly.graph_objects as go
import plotly.io as pio
 
pio.templates.default = "plotly" # ["plotly", "plotly_white", "plotly_dark", "ggplot2", "seaborn", "simple_white", "none"]:


fig = go.Figure()

fig.add_trace(
    go.Scatter(
        x=bird_standardized[:,0],
        y=bird_standardized[:,1],
        mode='markers',
        marker=dict(
        size=10,
        colorscale='Viridis',   # choose a colorscale
        opacity=0.9
    )
        
))

fig.add_trace(
    go.Scatter(
        x=[0],
        y=[0],
        mode='markers',
        marker=dict(
        size=20,
        colorscale='Viridis',   # choose a colorscale
        opacity=0.9
    )
    
    )

)
        

fig.update_yaxes(scaleanchor = "x",scaleratio = 1)
fig.update_layout(
    title="Bird_standardized with unit standard deviation",
    showlegend=False,
    xaxis_title="X Axis",
    yaxis_title="Y Axis ",
    font=dict(
        family="Courier New, monospace",
        size=18,
        color="Blue",
    )
)

# %% [markdown]
# # Pandas: Data Cleaning and preparation
# <b>Q2:Below is a way Load [California housing dataset](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.fetch_california_housing.html#examples-using-sklearn-datasets-fetch-california-housing
# ), and do the following:
# -  Link of the details: https://raw.githubusercontent.com/flyandlure/datasets/master/housing.csv
#
# 1. Use `df.info()` to check the type and counts of the attributes. Which attribute has missing values?
# 2. Identify missing values for each attribute of California housing dataset and sort in assending order.
# 3. Remove missing values and save the dataset as df_clean.csv and check again if missing values exist.
# 4. Show its descriptive statistics.
# 5. Generate the correlation matrix and plot correlation between attributes.
# 6. USe Seaborn to generate a correlation plot and answer the next question using this plot.
# </b>

# %%
df = pd.read_csv('https://raw.githubusercontent.com/flyandlure/datasets/master/housing.csv')
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# **Q3** Based on the California house dataset's correlation plot, answer the following question:
#
# 1. Which attribute are **highly positive and negative correlated**?
# 2. Identify those redundant attributes to remove for predicting the house price: median_house_value?

# %% [markdown]
# # Dimensionality Reduction

# %% [markdown]
# # Using `sklearn`: PCA

# %% [markdown]
# We will use a point cloud bird.csv to carry out PCA tasks.

# %% [markdown]
# **Q4** Load the bird.csv data and answer the following question:
#
# 1. Display the $\beta\gamma^{th}$ object of the data
# 2. Standardize the dataset using  scikit-learn package and identify type of output.
# 3. Display the $\beta\gamma^{th}$ object of the standardized data
# 4. Using scikit-learn package, compute the first two principal component and display the variability percentage each component preserves.
# 5. The data can be visualized in 1D plot, use the first principal component (2D projected to 1D) to visualize.
# 6. Similarly, use the second principal component to visualize.
# 7. Plot the standardized data on top of the two principal components which you derived earlier.

# %% [markdown]
# ### Load Data

# %%
import pandas as pd
bird = pd.read_csv("bird.csv")

# %% [markdown]
# Standarize the bird by using sk learn

# %%
import plotly.graph_objects as go
import plotly.io as pio
 
pio.templates.default = "plotly" # ["plotly", "plotly_white", "plotly_dark", "ggplot2", "seaborn", "simple_white", "none"]:


fig = go.Figure()

fig.add_trace(
    go.Scatter(
        x=converted_bird1[:,0].flatten(),
        y=np.zeros(1000),
        mode='markers',
        marker=dict(
        size=5,
        color='Orange',   # choose a colorscale
        opacity=0.3
    )
        
))

fig.add_trace(
    go.Scatter(
        x=[0],
        y=[0],
        mode='markers',
        marker=dict(
        size=10,
        colorscale='Viridis',   # choose a colorscale
        opacity=0.9
    )
    
    )

)
        

fig.update_yaxes(scaleanchor = "x",scaleratio = 1)
fig.update_layout(
    title="First Principal Component",
    showlegend=False,
    xaxis_title="PCA 1",
    #yaxis_title="Y Axis ",
    font=dict(
        family="Courier New, monospace",
        size=18,
        color="Blue",
    )
)

# %%
import plotly.graph_objects as go
import plotly.io as pio
 
pio.templates.default = "plotly" # ["plotly", "plotly_white", "plotly_dark", "ggplot2", "seaborn", "simple_white", "none"]:


fig = go.Figure()

fig.add_trace(
    go.Scatter(
        y=converted_bird1[:,1].flatten(),
        x=np.zeros(1000),
        mode='markers',
        marker=dict(
        size=5,
        color='Magenta',   # choose a colorscale
        opacity=0.3
    )
        
))

fig.add_trace(
    go.Scatter(
        x=[0],
        y=[0],
        mode='markers',
        marker=dict(
        size=10,
        colorscale='Viridis',   # choose a colorscale
        opacity=0.9
    )
    
    )

)
        

fig.update_yaxes(scaleanchor = "x",scaleratio = 1)
fig.update_layout(
    title="Second Principal Component",
    showlegend=False,
    yaxis_title="PCA 2",

    font=dict(
        family="Courier New, monospace",
        size=18,
        color="Blue",
    )
)

# %%
import plotly.graph_objects as go
import plotly.io as pio
 
pio.templates.default = "plotly" # ["plotly", "plotly_white", "plotly_dark", "ggplot2", "seaborn", "simple_white", "none"]:


fig = go.Figure()

#SKLEARN PCA 1 and PCA 2
fig.add_trace(
    go.Scatter(
        x=converted_bird1[:,0].flatten(),
        y=converted_bird1[:,1].flatten(),
        mode='markers',
        marker=dict(
        size=5,
        colorscale='Viridis',   # choose a colorscale
        opacity=0.5
    )
        
))

fig.add_trace(
    go.Scatter(
        x=[0],
        y=[0],
        mode='markers',
        marker=dict(
        size=10,
        colorscale='Viridis',   # choose a colorscale
        opacity=0.9
    )
    
    )

)

# PCA1
fig.add_trace(
    go.Scatter(
        x=converted_bird1[:,0].flatten(),
        y=np.zeros(1000),
        mode='markers',
        marker=dict(
        size=5,
        color='Orange',   # choose a colorscale
        opacity=0.3
    )
        
))

#PCA2
fig.add_trace(
    go.Scatter(
        x=np.zeros(1000),
        y=converted_bird1[:,1].flatten(),
        mode='markers',
        marker=dict(
        size=5,
        color='Magenta',   # choose a colorscale
        opacity=0.3
    )
        
))
        

fig.update_yaxes(scaleanchor = "x",scaleratio = 1)
fig.update_layout(
    title="SKLEARN: PC 1 & PC 2",
    showlegend=False,
    xaxis_title="PC 1",
    yaxis_title="PC 2",
    font=dict(
        family="Courier New, monospace",
        size=18,
        color="Blue",
    )
)

# %% [markdown]
# # Manual: STEP BY STEP PCA

# %% [markdown]
# - Section below will guide you how to use an [eigendecomposition](https://en.wikipedia.org/wiki/Eigendecomposition_of_a_matrix) to compute PCA.
#  - We will use bird dataset with 1000 points in 2D to carry out PCA.

# %% [markdown]
# ## PCA: Step by step eigen decomposition

# %% [markdown]
# **Q5:** 1. Find covariance matrix the dataset bird after standardizing.

# %% [markdown]
# **Q6:**
# 2. compute eigen vectors / eigen values

# %% [markdown]
# **Q7:** 3. Check how good did the new dimension preserved its original variability

# %% [markdown]
# **Q8:** Plot the direction of eigen vectors which will be the new axis

# %%
import plotly.graph_objects as go
import plotly.io as pio
import plotly.figure_factory as ff
 
pio.templates.default = "plotly" # ["plotly", "plotly_white", "plotly_dark", "ggplot2", "seaborn", "simple_white", "none"]:


# Drawing the eigen vectors
fig=ff.create_quiver(
    x=[bird.mean()[0]]*2, #start
    y=[bird.mean()[1]]*2,
    u=eig_vecs[:,0]*100, #end
    v=eig_vecs[:,1]*100,
    scale=1,
    arrow_scale=0.1,
    name='quiver',
    line=dict(
        width=5,
        color = 'black'))

#standardized bird
fig.add_trace(
    go.Scatter(
        x=bird['# x'],
        y=bird[' y'],
        mode='markers',
        marker=dict(
        size=5,
        colorscale='Viridis',  # choose a colorscale
        opacity=0.3
    )
        
))


fig.add_trace(
    go.Scatter(
        x=[bird.mean()[0]],
        y=[bird.mean()[1]],
        mode='markers',
        marker=dict(
        size=20,
        color='Red',   # choose a colorscale
        opacity=0.9
    )
    
    )

)

fig.update_yaxes(scaleanchor = "x",scaleratio = 1)


fig.update_layout(
    title="The direction of eigen vectors",
    showlegend=False,
    xaxis_title="X Axis",
    yaxis_title="Y Axis ",
    font=dict(
        family="Courier New, monospace",
        size=18,
        color="Blue",
    )
)

# %% [markdown]
# **Q9:** 4. Project data to its original 2D space using eigen vectors

# %%
import plotly.graph_objects as go
import plotly.io as pio
 
pio.templates.default = "plotly" # ["plotly", "plotly_white", "plotly_dark", "ggplot2", "seaborn", "simple_white", "none"]:


fig = go.Figure()

#using calculated PCA 1 & PCA2#
fig.add_trace(
    go.Scatter(
        x=BirdPCA1,
        y=BirdPCA2,
        mode='markers',
        marker=dict(
        size=5,
        color='red',   # choose a colorscale
        opacity=0.3
    )
        
))


# new standardized mean

fig.add_trace(
    go.Scatter(
        x=[0],
        y=[0],
        mode='markers',
        marker=dict(
        size=20,
        colorscale='Viridis',   # choose a colorscale
        opacity=0.9
    )
    
    )

)




# PCA1
fig.add_trace(
    go.Scatter(
        x=BirdPCA1,
        y=np.zeros(1000),
        mode='markers',
        marker=dict(
        size=5,
        color='Orange',   # choose a colorscale
        opacity=0.3
    )
        
))

#PCA2
fig.add_trace(
    go.Scatter(
        x=np.zeros(1000),
        y=BirdPCA2,
        mode='markers',
        marker=dict(
        size=5,
        color='Magenta',   # choose a colorscale
        opacity=0.3
    )
        
))

        
fig.update_yaxes(scaleanchor = "x",scaleratio = 1)
fig.update_layout(
    title="PCA Projection based on computed eigen vectors",
    showlegend=False,
    xaxis_title="PC 1",
    yaxis_title="PC 2",
    font=dict(
        family="Courier New, monospace",
        size=18,
        color="Blue",
    )
)

# %% [markdown]
# # Bonus: Reduce the dimension of Iris Dataset which is in 4D into 2D and plot it with scatter plot using PCA. Color the objects based in the type of the flower.

# %% [markdown]
# - Use scikit-learn to download the data and its PCA!
